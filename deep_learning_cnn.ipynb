# %%
import tensorflow as tf

# %%
(train_images, train_labels),(test_images, test_labels)= tf.keras.datasets.cifar10.load_data()

# %% [markdown]
# (train_images, train_labels),(test_images, test_labels)= tf.keras.datasets.cifar10.load_data()

# %%
print(train_images.shape)
# Out:
# (50000, 32, 32, 3)

# %%
def get_labels(idx):
    labels= ['airplane', 'deer', 'bird', 'truck', 'cat', 'dog', 'frog', 'horse', 'ship', 'automobile']
    return labels[idx]

# %%
import matplotlib.pyplot as plt

# %%
img= train_images[20]
plt.figure(figsize=(25,25))
plt.imshow(img)
plt.show()

# %% [markdown]
# ## making cnn architecture

# %%
model= tf.keras.Sequential()

# %%
model.add(
    tf.keras.layers.Conv2D(filters= 10, kernel_size= (3,3),input_shape= (32,32,3), activation= 'relu')
)

# %%
model.add(
    tf.keras.layers.MaxPool2D()
)

# %%
model.add(
    tf.keras.layers.Flatten(input_shape=[32,32])
)

# %%
model.add(
    tf.keras.layers.Dense(units= 28, activation= 'relu')
)

# %%
model.add(
    tf.keras.layers.Dense(units= 10, activation= 'softmax')
)

# %%
model.compile('adam',loss= 'sparse_categorical_crossentropy', metrics= ['accuracy'])

# %%
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# conv2d_1 (Conv2D)            (None, 30, 30, 10)        280
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 15, 15, 10)        0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 2250)              0
# _________________________________________________________________
# dense_2 (Dense)              (None, 28)                63028
# _________________________________________________________________
# dense_3 (Dense)              (None, 10)                290
# ...
# Total params: 63,598
# Trainable params: 63,598
# Non-trainable params: 0
# _________________________________________________________________

# %%
history = model.fit(train_images, train_labels, epochs=5, validation_data= (test_images, test_labels))
# Out:
# Epoch 1/5
# 1563/1563 [==============================] - 14s 9ms/step - loss: 2.5419 - accuracy: 0.0969 - val_loss: 2.3026 - val_accuracy: 0.1000
# Epoch 2/5
# 1563/1563 [==============================] - 13s 8ms/step - loss: 2.3028 - accuracy: 0.0988 - val_loss: 2.3026 - val_accuracy: 0.1000
# Epoch 3/5
# 1563/1563 [==============================] - 13s 8ms/step - loss: 2.3028 - accuracy: 0.0990 - val_loss: 2.3026 - val_accuracy: 0.1000
# Epoch 4/5
#  329/1563 [=====>........................] - ETA: 10s - loss: 2.3026 - accuracy: 0.0997
